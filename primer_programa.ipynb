# %% [markdown]
# # Titulo: Primeros pasos Python

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
prin("Hola")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 prin("Hola")
#
# NameError: name 'prin' is not defined

# %%
nombre = "Juan"

# %%
print(nombre)
# Out:
# Juan

# %%
print(type(nombre))
# Out:
# <class 'str'>

# %%
edad = 20
estatura = 1.65
letra = "a"

# %%
print(type(edad))
print(type(estatura))
print(type(letra)) #Comentarios
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## Tipos de datos
#
# - int
# - float
# - string
# - bool

# %% [markdown]
# # Operadores aritméticos
#
# - suma: +
# - resta: -
# - multiplicación: *
# - división: /
# - división entero: //
# - residuo: %
# - potencia: **
# - multiplicación de matrices: &

# %%
a = 10
b = 3

print(a//b)
print(a%b)
# Out:
# 3
# 1

# %% [markdown]
# # Operadores de comparación
# - <>
# - ==
# - !=

# %% [markdown]
# ## Entrada y salida de datos

# %%
nombre = input("Ingrese su nombre: ")
print(nombre)
# Out:
# Susana

# %%
edad = input("Ingrese su edad: ")
print(type(edad))
# Out:
# <class 'str'>

# %%
nombre = input("Ingrese su nombre: ")
edad = input("Ingrese su edad: ")
ciudad = input("Ingrese su ciudad: ")

print()
print("==== INFORMACIÓN DEL ESTUDIANTE ====")
print("Nombre:", nombre)
print("Edad:", edad)
print("Ciudad:", ciudad)
# Out:
# ==== INFORMACIÓN DEL ESTUDIANTE ====
# Nombre: Susana
# Edad: 15
# Ciudad: Medell[in
